# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np

# %%
df = pd.read_csv('data/heart_disease_uci.csv')

# %% [markdown]
# One of the major tasks on this dataset is to predict based on the given attributes of a patient that whether that particular person has heart disease or not and other is the experimental task to diagnose and find out various insights from this dataset which could help in understanding the problem more.

# %%
pazienti_non_malati = df[df['num'] == 0]
pazienti_malati = df[df['num'] != 0]

pazienti_malati['num'].isnull().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB

# %%
# Draw a histogram to check the distribution of age column

histplot = sns.histplot(data=df, x='age', hue='sex', multiple='stack', palette={'Male': 'blue', 'Female': 'pink'}, kde=True)

# Impostiamo le etichette degli assi
histplot.set_xlabel("Età pazienti")
histplot.set_ylabel("Numero di pazienti")

# Impostiamo il titolo del grafico
histplot.set_title('Istogramma per il numero di pazienti suddivisi in età')

# Mostriamo il grafico
plt.show()

# %%
df['group'] = df['num'].apply(lambda x: 0 if x == 0 else 1)

histplot = sns.histplot(data=df, x='age', hue='sex', multiple='stack', palette={'Male': 'blue', 'Female': 'pink'}, kde=True)

# Impostiamo le etichette degli assi
histplot.set_xlabel("Età pazienti")
histplot.set_ylabel("Numero di pazienti")

# Impostiamo il titolo del grafico
histplot.set_title('Istogramma per il numero di pazienti suddivisi in età')

# Mostriamo il grafico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/7s/vj63v_px0_nbz2g7wwbmgv7r0000gn/T/ipykernel_9094/321307168.py in <module>
#       1 df['group'] = df['num'].apply(lambda x: 0 if x == 0 else 1)
#       2
# ----> 3 histplot = sns.histplot(data=df, x='age', hue='sex', multiple='stack', palette={'Maschio': 'blue', 'Female': 'pink'}, kde=True)
#       4
#       5 # Impostiamo le etichette degli assi
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1433     )
#    1434
# -> 1435     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#    1436
#    1437     if ax is None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py in map(cls, plotter, *args, **kwargs)
#      51         # This method is assigned the __init__ docstring
#      52         method_name = "_{}_map".format(cls.__name__[:-7].lower())
# ---> 53         setattr(plotter, method_name, cls(plotter, *args, **kwargs))
#      54         return plotter
#      55
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py in __init__(self, plotter, palette, order, norm)
#     116
#     117                 cmap = norm = None
# --> 118                 levels, lookup_table = self.categorical_mapping(
#     119                     data, palette, order,
#     120                 )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py in categorical_mapping(self, data, palette, order)
#     188             if any(missing):
#     189                 err = "The palette dictionary is missing keys: {}"
# --> 190                 raise ValueError(err.format(missing))
#     191
#     192             lookup_table = palette
#
# ValueError: The palette dictionary is missing keys: {'Male'}
